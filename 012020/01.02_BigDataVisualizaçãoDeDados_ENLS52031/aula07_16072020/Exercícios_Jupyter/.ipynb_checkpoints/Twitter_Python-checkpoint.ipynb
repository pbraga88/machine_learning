# %% [markdown]
# http://docs.tweepy.org/en/v3.5.0/api.html#tweepy-api-twitter-api-wrapper

# %%
#!pip install tweepy

# %%
import tweepy

# %%
consumer_key = "GR4yLjrkzEHNQo0YeUJrgRmyL"
consumer_secret = "9oQ73TOXdW3NwONWXdNhFbWb8cszjZDBh8Xwjupf52QcYelZFH"
access_token = "1283872626461552643-R4bSHvbxdU2eyDDUUMqIfYMTZeViiW"
access_secret = "oMDDmKy4TJn9lXhZmrm5s74AGYnuxEn0821us07zKMUVE"

# %%
autenticacao = tweepy.OAuthHandler(consumer_key, consumer_secret)
autenticacao.set_access_token(access_token, access_secret)

# %%
twitter = tweepy.API(autenticacao)

# %%
user = twitter.get_user("simplicio_braga")

nome = user.name
descricao = user.description
localizacao = user.location

print("Usuário:", nome,"| Descrição:", descricao, "| Localização:", localizacao)
# Out:
# Usuário: Paulo Simplício Braga | Descrição:  | Localização:

# %%
seguidores = twitter.followers("simplicio_braga")

for seguidor in seguidores:
    print(seguidor.screen_name)

# %%
retornoTwitter = twitter.search(q="Barak Obama", lang="en", rpp=50)

for tweet in retornoTwitter:
    print(f"Usuário",tweet.user.name, 'escreveu',tweet.text)
    print("#############")
    
len(retornoTwitter)
# Out:
# Usuário Gohy escreveu RT @scspcommunity: (1/4) Two days back, Twitter was hacked and a Bitcoin scam was started.
# Accounts of celebrities, business tycoons and bi…
# #############
# Usuário K8 escreveu @bitsandsnatches @matcha_chai Ask George Bush and Barak Obama and Joe Biden about disappearing rights! Methinks you… https://t.co/vqtdloue12
# #############
# Usuário sm escreveu Totally agree Barak tbe Terrorists Hussain Ben Obama the undercover Muslims Brotherhood operative . @Ramy_Aziz1 https://t.co/xpg8IEMhK4
# #############
# Usuário rnora escreveu Barak Obama's library: a beautiful project that might need re-location
# https://t.co/9QrT9ZTF8f
# #############
# Usuário Imam Murrah escreveu @BroHajji @YouTube Its not hussain ibn ali ibn abi talib. Its Barak hussain Obama. (I watched the video)
# #############
# ...

# %%
twitter.trends_available()
# Out:
# [{'name': 'Worldwide',
#   'placeType': {'code': 19, 'name': 'Supername'},
#   'url': 'http://where.yahooapis.com/v1/place/1',
#   'parentid': 0,
#   'country': '',
#   'woeid': 1,
#   'countryCode': None},
#  {'name': 'Winnipeg',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/2972',
#   'parentid': 23424775,
#   'country': 'Canada',
#   'woeid': 2972,
#   'countryCode': 'CA'},
#  {'name': 'Ottawa',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3369',
#   'parentid': 23424775,
#   'country': 'Canada',
#   'woeid': 3369,
#   'countryCode': 'CA'},
#  {'name': 'Quebec',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3444',
#   'parentid': 23424775,
#   'country': 'Canada',
#   'woeid': 3444,
#   'countryCode': 'CA'},
#  {'name': 'Montreal',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3534',
# ...

# %%
#trends_result = twitter.trends_place(23424768) #Brazil
trends_result = twitter.trends_place(455827) #São Paulo
termo = trends_result[0]["trends"][0]["name"]

# %%
# trends_result

# %%
print(termo)
retornoTwitter = twitter.search(q='NLP', lang="en", n=5000,\
                               since="2020-07-01")

# for tweet in retornoTwitter:
#     print(f"Usuário",tweet.user.name, 'escreveu',tweet.text)
#     print("#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#")
# Out:
# #BDSP

# %%
len(retornoTwitter)
# Out:
# 15

# %%
import texthero as hero
import pandas as pd

# %%
data = {'tweet': []}
df = pd.DataFrame(data=data)

# %%
for tweet in retornoTwitter:
    df= df.append({'tweet':tweet.text}, ignore_index=True)

# %%
df
# Out:
#                                                 tweet
# 0   RT @Deep_In_Depth: These drones won't fly into...
# 1   *****Just 3 days left*****\nGet the NLP diplom...
# 2   NLP poised to revolutionize the enterprise htt...
# 3   Check out NLP's #COVID__19 specific page on mi...
# 4   RT @chaitjo: Excited to share a blog post on t...
# 5   @QiaochuYuan @DaltonDEmery @visakanv As someon...
# 6   RT @sanksshep: Google’s secretive ATAP lab is ...
# 7   RT @bijurao: If you specialize in #NLP (from a...
# 8   RT @bijurao: If you specialize in #NLP (from a...
# 9   RT @sanksshep: Google’s secretive ATAP lab is ...
# 10  RT @sanksshep: Google’s secretive ATAP lab is ...
# 11  RT @sanksshep: Google’s secretive ATAP lab is ...
# 12  RT @sanksshep: Google’s secretive ATAP lab is ...
# 13  @RusslAndrewsHat Hahaha - machine learning is ...
# 14  NLP poised to revolutionize the enterprise htt...

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
df['tweet'] = hero.clean(df['tweet'])

# %%
NUM_TOP_WORDS = 100
frequencia_de_palavras = hero.top_words(df['tweet'])[:NUM_TOP_WORDS]

# %%
wordcloud = WordCloud()
wordcloud.generate_from_frequencies(frequencies=frequencia_de_palavras)

# %%
plt.figure(figsize=(15,8))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from texthero import stopwords

# %%
default_stopwords = stopwords.DEFAULT

#add a list of stopwords to the stopwords
custom_stopwords = default_stopwords.union(set(["https", "co"]))

# %%
df['tweet'] = hero.remove_stopwords(df['tweet'],\
                                          custom_stopwords)

# %%
NUM_TOP_WORDS = 100
frequencia_de_palavras = hero.top_words(df['tweet'])[:NUM_TOP_WORDS]

# %%
wordcloud = WordCloud()
wordcloud.generate_from_frequencies(frequencies=frequencia_de_palavras)

# %%
plt.figure(figsize=(15,8))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

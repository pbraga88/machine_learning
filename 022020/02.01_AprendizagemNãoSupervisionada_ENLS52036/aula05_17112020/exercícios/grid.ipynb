# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.array([[1,3],[3,1]])
for i in range(1,11):
    for j in range(1,11):
        plt.plot(i,j,'bo')
        prod=np.dot(A, np.array([i,j]))
        plt.plot(prod[0], prod[1], 'ro')
plt.show()

# %%
import pandas as pd
df=pd.read_excel('municipios.xlsx')
df.head()
# Out:
#     ANO  Código da Unidade da Federação  ... IDHM Longevidade  IDHM Renda
# 0  2010                              35  ...            0.852       0.772
# 1  2010                              35  ...            0.844       0.710
# 2  2010                              35  ...            0.858       0.703
# 3  2010                              35  ...            0.886       0.750
# 4  2010                              35  ...            0.846       0.725
#
# [5 rows x 237 columns]

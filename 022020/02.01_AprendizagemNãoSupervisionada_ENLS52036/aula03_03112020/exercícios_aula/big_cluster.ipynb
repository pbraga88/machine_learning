# %%
import pandas as pd
import numpy as np
df=pd.read_excel('municipios.xlsx')
df.head(10)
# Out:
#     ANO  Código da Unidade da Federação Nome da Unidade da Federação  \
# 0  2010                              35                    São Paulo
# 1  2010                              35                    São Paulo
# 2  2010                              35                    São Paulo
# 3  2010                              35                    São Paulo
# 4  2010                              35                    São Paulo
# 5  2010                              35                    São Paulo
# 6  2010                              35                    São Paulo
# 7  2010                              35                    São Paulo
# 8  2010                              35                    São Paulo
# 9  2010                              35                    São Paulo
#
#    Código do Município               Município  Esperança de vida ao nascer  \
# 0               350010              ADAMANTINA                        76.13
# ...

# %%
list(df.columns)
# Out:
# ['ANO',
#  'Código da Unidade da Federação',
#  'Nome da Unidade da Federação',
#  'Código do Município',
#  'Município',
#  'Esperança de vida ao nascer',
#  'Taxa de fecundidade total',
#  'Mortalidade infantil',
#  'Mortalidade até 5 anos de idade',
#  'Razão de dependência',
#  'Probabilidade de sobrevivência até 40 anos',
#  'Probabilidade de sobrevivência até 60 anos',
#  'Taxa de envelhecimento',
#  'Expectativa de anos de estudo',
#  'Taxa de analfabetismo - 11 a 14 anos',
#  'Taxa de analfabetismo - 15 a 17 anos',
#  'Taxa de analfabetismo - 15 anos ou mais',
#  'Taxa de analfabetismo - 18 a 24 anos',
#  'Taxa de analfabetismo - 18 anos ou mais',
#  'Taxa de analfabetismo - 25 a 29 anos',
#  'Taxa de analfabetismo - 25 anos ou mais',
#  '% de 6 a 17 anos no básico sem atraso',
#  '% de 6 a 14 anos no fundamental sem atraso',
#  '% de 15 a 17 anos no médio sem atraso',
#  '% de 6 a 17 no básico com 1 ano de atraso',
#  '% de 6 a 14 anos no fundamental com 1 ano de atraso',
# ...

# %%
df.describe()
# Out:
#           ANO  Código da Unidade da Federação  Código do Município  \
# count   645.0                           645.0           645.000000
# mean   2010.0                            35.0        352869.334884
# std       0.0                             0.0          1670.029961
# min    2010.0                            35.0        350010.000000
# 25%    2010.0                            35.0        351460.000000
# 50%    2010.0                            35.0        352870.000000
# 75%    2010.0                            35.0        354320.000000
# max    2010.0                            35.0        355730.000000
#
#        Esperança de vida ao nascer  Taxa de fecundidade total  \
# count                   645.000000                 645.000000
# mean                     75.153984                   1.956884
# std                       1.316245                   0.329102
# min                      71.490000                   1.250000
# ...

# %%
dfn=df[df['Município']!='SÃO PAULO'].copy()

# %%
mun=df['Município'].copy()
mun
# Out:
# 0            ADAMANTINA
# 1                ADOLFO
# 2                 AGUAÍ
# 3        ÁGUAS DA PRATA
# 4      ÁGUAS DE LINDÓIA
#              ...
# 640          VOTORANTIM
# 641         VOTUPORANGA
# 642            ZACARIAS
# 643           CHAVANTES
# 644        ESTIVA GERBI
# Name: Município, Length: 645, dtype: object

# %%
# drop first columns
dfn = df.iloc[:,5:].copy()

# %%
dfn.head()
# Out:
#    Esperança de vida ao nascer  Taxa de fecundidade total  \
# 0                        76.13                       1.40
# 1                        75.62                       1.81
# 2                        76.49                       2.14
# 3                        78.13                       1.81
# 4                        75.76                       1.52
#
#    Mortalidade infantil  Mortalidade até 5 anos de idade  \
# 0                  12.0                            13.92
# 1                  13.8                            15.98
# 2                  12.5                            14.50
# 3                   9.6                            11.13
# 4                  12.5                            14.50
#
#    Razão de dependência  Probabilidade de sobrevivência até 40 anos  \
# 0                 42.86                                       94.72
# 1                 42.22                                       94.76
# ...

# %%
X = np.array(dfn)
X[:3]
# Out:
# array([[7.61300e+01, 1.40000e+00, 1.20000e+01, 1.39200e+01, 4.28600e+01,
#         9.47200e+01, 8.50600e+01, 1.26100e+01, 1.03900e+01, 9.60000e-01,
#         9.30000e-01, 6.14000e+00, 7.30000e-01, 6.44000e+00, 9.70000e-01,
#         7.42000e+00, 7.93600e+01, 8.07500e+01, 8.35300e+01, 1.21100e+01,
#         1.14600e+01, 1.36500e+01, 8.53000e+00, 7.79000e+00, 2.82000e+00,
#         9.05600e+01, 9.82400e+01, 7.26800e+01, 9.08300e+01, 4.13400e+01,
#         8.59700e+01, 9.19300e+01, 5.73400e+01, 8.08400e+01, 2.48400e+01,
#         3.17600e+01, 9.67900e+01, 8.06600e+01, 2.93300e+01, 8.80000e+00,
#         8.93400e+01, 9.02400e+01, 9.19500e+01, 9.26600e+01, 9.75500e+01,
#         9.24800e+01, 8.42000e+00, 2.40000e-01, 3.60000e+00, 3.32000e+00,
#         2.72000e+00, 3.56000e+00, 9.29100e+01, 9.52500e+01, 7.78600e+01,
#         8.58600e+01, 8.93600e+01, 6.07900e+01, 5.58800e+01, 7.03000e+01,
#         7.05700e+01, 4.61100e+01, 7.18500e+01, 4.19000e+01, 1.64900e+01,
# ...

# %%
# Standarlizar as features pois as ordens de grandeza são muito diferentes
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaler.fit(X)
XS=scaler.transform(X)
XS[:10,:20]
# Out:
# array([[ 0.74209053, -1.69344672, -1.12568322, -1.10628556, -0.46711253,
#          0.39502068,  0.81864132,  1.51149027, -0.15221125, -0.59788825,
#         -0.28621083, -0.55808665, -0.98404766, -0.5744354 , -0.94627765,
#         -0.58286134,  0.56182154,  0.43472542,  0.06212072, -0.46152501],
#        [ 0.35432397, -0.44666372, -0.29822651, -0.28725083, -0.61796964,
#          0.45208734,  0.37154695,  0.64017959, -0.50443735, -2.03913248,
#          0.1824909 ,  0.18065901, -0.9410582 ,  0.15532513, -0.2204629 ,
#          0.14670217, -0.0198784 ,  0.21572689, -1.65794941, -0.11703829],
#        [ 1.0158081 ,  0.55684455, -0.89583413, -0.87568355, -0.27382686,
#          1.10835385,  1.01619465, -0.5386525 , -2.617794  ,  1.83421139,
#          1.24488148,  0.03216742,  1.03645703,  0.02389906,  0.79567775,
#          0.01567852, -2.80591495, -3.00824434, -0.85268422,  1.9881583 ],
#        [ 2.26274369, -0.44666372, -2.22895882, -2.21556075,  0.33903016,
# ...

# %%
XS[:,0].mean() # Média = 0
# Out:
# 4.6495107505697256e-15

# %%
XS[:,0].std() # Desvio padrão = 1
# Out:
# 1.0

# %%
from sklearn.cluster import KMeans

# %%
km=KMeans(n_clusters=5, random_state=5)

km.fit(XS)
km.inertia_
# Out:
# 74554.94044014667

# %%
import matplotlib.pyplot as plt

# %%
lk=[]
lc=[]
ls=[]
for i in range(2,21):
    km=KMeans(n_clusters=i, random_state=5)
    km.fit(XS)
    lk.append(i)
    lc.append(km.inertia_)
    ls.append(silhouette_score(X, km.labels_))
plt.plot(lk, lc, color = 'black')
plt.show()
plt.plot(lk, ls, color = 'black')
plt.show()

# %%
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
silhouette_avg = silhouette_score(X, km.labels_)

# %%
silhouette_avg
# Out:
# -0.36654447176470767

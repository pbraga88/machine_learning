# %%
#!pip install texthero

# %%
import texthero as hero
import pandas as pd
# Out:
# [nltk_data] Downloading package stopwords to /home/pbraga/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
df = pd.read_csv("Dataset/Twitter_Brasil.csv", sep=";")
df.head(2)
# Out:
#    Unnamed: 0  X                                               text  \
# 0           1  1  rt twitterbrasil com 5 milhoes tweets brasil f...
# 1           2  2  rt exame inspirado por huck silvio �anuncia� c...
#
#    favorited  favoriteCount replyToSN              created  truncated  \
# 0      False              0       NaN  2017-05-22 18:40:42      False
# 1      False              0       NaN  2017-05-22 18:40:42      False
#
#   replyToSID                  id  replyToUID  \
# 0        NaN  866725523799629824         NaN
# 1        NaN  866725523325628416         NaN
#
#                                         statusSource  screenName  \
# 0  <a href="http://twitter.com/download/iphone" r...  dressaa_eu
# 1  <a href="http://twitter.com/download/android" ...    to_brabo
#
#    retweetCount  isRetweet  retweeted longitude latitude
# 0            36       True      False       NaN      NaN
# 1           136       True      False       NaN      NaN

# %%
df['text']
# Out:
# 0       rt twitterbrasil com 5 milhoes tweets brasil f...
# 1       rt exame inspirado por huck silvio �anuncia� c...
# 2       gostaria saber como ixar ser a mulher mais sor...
# 3       rt cynaramenezes quais as razoes ocultas para ...
# 4       quem tem medo da mocracia  brasil 247 via bras...
#                               ...
# 9995               pobre quem acredita nele isso e brasil
# 9996    rt opovoonline silvio santos diz que sera cand...
# 9997    rt agoranoplanalto �fenremos o brasil� afirma ...
# 9998    pgiolli rmelette paulox36 joclau53 chefpalmiri...
# 9999    rt cidadaodopovo no brasil da posverda gravaca...
# Name: text, Length: 10000, dtype: object

# %%
df['text'] = hero.clean(df['text'])

# %%
NUM_TOP_WORDS = 100
frequencia_de_palavras = hero.top_words(df['text'])[:NUM_TOP_WORDS]

# %%
#frequencia_de_palavras = frequencia_de_palavras.toPandas()

# %% [markdown]
# # Word Cloud

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
wordcloud = WordCloud()
wordcloud.generate_from_frequencies(frequencies=frequencia_de_palavras)

# %%
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
